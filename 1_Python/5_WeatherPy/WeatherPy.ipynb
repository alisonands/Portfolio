# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#Empty list for holging lat, long, and cities
lat_lngs = []
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# random set of lat and lng coords:
lats = np.random.uniform(lat_range[0], lat_range[1], size = 1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size = 1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ## Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list

# %%
base_url = 'https://api.openweathermap.org/data/2.5/weather?'

city_data = []
#set units
units = 'metric'

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if ((i % 50 == 0 )and (i >= 50)):
        set_count +=1
        record_count = 0

    # endpoint url for each city
    city_url = f'{base_url}q={city}&appid={weather_api_key}&units={units}'

    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    record_count += 1

    try:
        city_weather = requests.get(city_url).json()

        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        city_data.append({
            "City": city, 
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })
    except:
        print(f"City {city} not found. Skipping/...")


print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | tir pul
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | mount gambier
# Processing Record 6 of Set 1 | sur
# Processing Record 7 of Set 1 | lovington
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | isafjordur
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | ancud
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | kingston
# Processing Record 14 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | puerto san carlos
# City puerto san carlos not found. Skipping/...
# Processing Record 17 of Set 1 | nagato
# Processing Record 18 of Set 1 | makurazaki
# Processing Record 19 of Set 1 | xining
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | pascagoula
# Processing Record 22 of Set 1 | grytviken
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | ed damer
# Processing Record 25 of Set 1 | adamstown
# Processing Record 26 of Set 1 | chesma
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | westport
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | warragul
# Processing Record 31 of Set 1 | wailua homesteads
# Processing Record 32 of Set 1 | kailua-kona
# Processing Record 33 of Set 1 | mahaddayweyne
# Processing Record 34 of Set 1 | port mathurin
# Processing Record 35 of Set 1 | college
# Processing Record 36 of Set 1 | whitehorse
# Processing Record 37 of Set 1 | nagqu
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | marand
# Processing Record 40 of Set 1 | iskateley
# Processing Record 41 of Set 1 | hadibu
# Processing Record 42 of Set 1 | cargados carajos
# City cargados carajos not found. Skipping/...
# Processing Record 43 of Set 1 | hopkinton
# Processing Record 44 of Set 1 | blackmans bay
# Processing Record 45 of Set 1 | alofi
# Processing Record 46 of Set 1 | remire-montjoly
# Processing Record 47 of Set 1 | acapulco de juarez
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | touros
# Processing Record 0 of Set 2 | dem'yanovo
# Processing Record 1 of Set 2 | xapuri
# Processing Record 2 of Set 2 | papatowai
# Processing Record 3 of Set 2 | achacachi
# Processing Record 4 of Set 2 | saint-pierre
# Processing Record 5 of Set 2 | tsiombe
# Processing Record 6 of Set 2 | howard springs
# Processing Record 7 of Set 2 | aylmer
# Processing Record 8 of Set 2 | dalbandin
# Processing Record 9 of Set 2 | kawm umbu
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | kudahuvadhoo
# Processing Record 12 of Set 2 | chala
# Processing Record 13 of Set 2 | severo-yeniseyskiy
# Processing Record 14 of Set 2 | stanley
# Processing Record 15 of Set 2 | san antonio de pale
# Processing Record 16 of Set 2 | wajir
# Processing Record 17 of Set 2 | port saint john's
# Processing Record 18 of Set 2 | mil'kovo
# Processing Record 19 of Set 2 | forster
# Processing Record 20 of Set 2 | liman
# Processing Record 21 of Set 2 | selfoss
# Processing Record 22 of Set 2 | nuuk
# Processing Record 23 of Set 2 | letterkenny
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | sendafa
# Processing Record 27 of Set 2 | invercargill
# Processing Record 28 of Set 2 | chela
# Processing Record 29 of Set 2 | jinchang
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | palikir - national government center
# Processing Record 32 of Set 2 | choyr
# Processing Record 33 of Set 2 | olonkinbyen
# Processing Record 34 of Set 2 | kununurra
# Processing Record 35 of Set 2 | manali
# Processing Record 36 of Set 2 | pudozh
# Processing Record 37 of Set 2 | novodvinsk
# Processing Record 38 of Set 2 | durban
# Processing Record 39 of Set 2 | atafu village
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | burang
# Processing Record 43 of Set 2 | 'ohonua
# City 'ohonua not found. Skipping/...
# Processing Record 44 of Set 2 | canyon
# Processing Record 45 of Set 2 | bilibino
# Processing Record 46 of Set 2 | edinburgh of the seven seas
# Processing Record 47 of Set 2 | viedma
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | ballina
# Processing Record 0 of Set 3 | torghay
# Processing Record 1 of Set 3 | leava
# Processing Record 2 of Set 3 | polyarnyy
# Processing Record 3 of Set 3 | vila franca do campo
# Processing Record 4 of Set 3 | abepura
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | lorengau
# Processing Record 7 of Set 3 | badger
# Processing Record 8 of Set 3 | nova sintra
# Processing Record 9 of Set 3 | inda silase
# Processing Record 10 of Set 3 | puerto armuelles
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | batangas
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | ceeldheer
# Processing Record 15 of Set 3 | papao
# Processing Record 16 of Set 3 | hawaiian paradise park
# Processing Record 17 of Set 3 | maiwut
# City maiwut not found. Skipping/...
# Processing Record 18 of Set 3 | flying fish cove
# Processing Record 19 of Set 3 | devinuwara
# City devinuwara not found. Skipping/...
# Processing Record 20 of Set 3 | tripoli
# Processing Record 21 of Set 3 | cleveland
# Processing Record 22 of Set 3 | san angelo
# Processing Record 23 of Set 3 | cobija
# Processing Record 24 of Set 3 | ain beni mathar
# City ain beni mathar not found. Skipping/...
# Processing Record 25 of Set 3 | barmer
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | nadym
# Processing Record 28 of Set 3 | yuzhno-kurilsk
# Processing Record 29 of Set 3 | aykhal
# Processing Record 30 of Set 3 | tazacorte
# Processing Record 31 of Set 3 | kapchorwa
# Processing Record 32 of Set 3 | lindi
# Processing Record 33 of Set 3 | fort st. john
# Processing Record 34 of Set 3 | settat
# Processing Record 35 of Set 3 | west island
# Processing Record 36 of Set 3 | bondowoso
# Processing Record 37 of Set 3 | colonia
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | qaqortoq
# Processing Record 40 of Set 3 | mount pearl
# Processing Record 41 of Set 3 | taiohae
# City taiohae not found. Skipping/...
# Processing Record 42 of Set 3 | la'ie
# Processing Record 43 of Set 3 | zhalantun
# Processing Record 44 of Set 3 | nova vicosa
# Processing Record 45 of Set 3 | kapuskasing
# Processing Record 46 of Set 3 | aral
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | aasiaat
# Processing Record 49 of Set 3 | susuman
# Processing Record 0 of Set 4 | loch garman
# Processing Record 1 of Set 4 | cipo
# Processing Record 2 of Set 4 | sona
# Processing Record 3 of Set 4 | jumla
# Processing Record 4 of Set 4 | roxas
# Processing Record 5 of Set 4 | portage la prairie
# Processing Record 6 of Set 4 | mwingi
# Processing Record 7 of Set 4 | bikenibeu village
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | al jawf
# Processing Record 10 of Set 4 | pemangkat
# Processing Record 11 of Set 4 | chillicothe
# Processing Record 12 of Set 4 | sovetskiy
# Processing Record 13 of Set 4 | selkirk
# Processing Record 14 of Set 4 | afaahiti
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | nantucket
# Processing Record 17 of Set 4 | shache
# Processing Record 18 of Set 4 | arkhangel'sk
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | songjiang
# Processing Record 21 of Set 4 | maasmechelen
# Processing Record 22 of Set 4 | porto novo
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | zapala
# Processing Record 25 of Set 4 | vadso
# Processing Record 26 of Set 4 | uitenhage
# Processing Record 27 of Set 4 | kerikeri
# Processing Record 28 of Set 4 | saudarkrokur
# Processing Record 29 of Set 4 | ishigaki
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | igarka
# Processing Record 32 of Set 4 | bamboo flat
# Processing Record 33 of Set 4 | vesoul
# Processing Record 34 of Set 4 | qarazhal
# Processing Record 35 of Set 4 | haiku-pauwela
# Processing Record 36 of Set 4 | okha
# Processing Record 37 of Set 4 | utrik
# Processing Record 38 of Set 4 | tarinkot
# Processing Record 39 of Set 4 | sault ste. marie
# Processing Record 40 of Set 4 | chui
# Processing Record 41 of Set 4 | fort bragg
# Processing Record 42 of Set 4 | dunedin
# Processing Record 43 of Set 4 | chegdomyn
# Processing Record 44 of Set 4 | richards bay
# Processing Record 45 of Set 4 | ichinoseki
# Processing Record 46 of Set 4 | puerto santa
# Processing Record 47 of Set 4 | ugoofaaru
# Processing Record 48 of Set 4 | santa ana
# Processing Record 49 of Set 4 | salalah
# Processing Record 0 of Set 5 | alaghsas
# Processing Record 1 of Set 5 | udachny
# Processing Record 2 of Set 5 | zakopane
# Processing Record 3 of Set 5 | krasnoslobodsk
# Processing Record 4 of Set 5 | sao joao da barra
# Processing Record 5 of Set 5 | port lincoln
# Processing Record 6 of Set 5 | lagdo
# Processing Record 7 of Set 5 | ixtapa
# Processing Record 8 of Set 5 | lihue
# Processing Record 9 of Set 5 | auki
# Processing Record 10 of Set 5 | cartagena
# Processing Record 11 of Set 5 | shenjiamen
# Processing Record 12 of Set 5 | ta`u
# Processing Record 13 of Set 5 | salekhard
# Processing Record 14 of Set 5 | keflavik
# Processing Record 15 of Set 5 | qal'at bishah
# City qal'at bishah not found. Skipping/...
# Processing Record 16 of Set 5 | porto velho
# Processing Record 17 of Set 5 | turochak
# Processing Record 18 of Set 5 | spring creek
# Processing Record 19 of Set 5 | taoudenni
# Processing Record 20 of Set 5 | bodaybo
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | albemarle
# Processing Record 23 of Set 5 | montevideo
# Processing Record 24 of Set 5 | drebkau
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | argo
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | sines
# Processing Record 29 of Set 5 | sychevka
# Processing Record 30 of Set 5 | kapa'a
# Processing Record 31 of Set 5 | ottawa
# Processing Record 32 of Set 5 | nizhneangarsk
# Processing Record 33 of Set 5 | pacific grove
# Processing Record 34 of Set 5 | bodo
# Processing Record 35 of Set 5 | alegrete
# Processing Record 36 of Set 5 | island harbour
# Processing Record 37 of Set 5 | forbes
# Processing Record 38 of Set 5 | fuvahmulah
# City fuvahmulah not found. Skipping/...
# Processing Record 39 of Set 5 | cockburn town
# Processing Record 40 of Set 5 | tonekabon
# Processing Record 41 of Set 5 | germantown
# Processing Record 42 of Set 5 | kasongo-lunda
# Processing Record 43 of Set 5 | altai
# Processing Record 44 of Set 5 | thompson
# Processing Record 45 of Set 5 | antofagasta
# Processing Record 46 of Set 5 | vorkuta
# Processing Record 47 of Set 5 | mudurnu
# Processing Record 48 of Set 5 | tabuk
# Processing Record 49 of Set 5 | poxoreo
# Processing Record 0 of Set 6 | san luis de la loma
# Processing Record 1 of Set 6 | kavaratti
# Processing Record 2 of Set 6 | boca do acre
# Processing Record 3 of Set 6 | ulladulla
# Processing Record 4 of Set 6 | ar rutbah
# Processing Record 5 of Set 6 | pangody
# Processing Record 6 of Set 6 | trapani
# Processing Record 7 of Set 6 | songea
# Processing Record 8 of Set 6 | lamu
# Processing Record 9 of Set 6 | pimampiro
# Processing Record 10 of Set 6 | tura
# Processing Record 11 of Set 6 | ola
# Processing Record 12 of Set 6 | revda
# Processing Record 13 of Set 6 | santiago de cao
# Processing Record 14 of Set 6 | chibougamau
# Processing Record 15 of Set 6 | ahau
# City ahau not found. Skipping/...
# Processing Record 16 of Set 6 | port alberni
# Processing Record 17 of Set 6 | hede
# Processing Record 18 of Set 6 | general conesa
# Processing Record 19 of Set 6 | dudinka
# Processing Record 20 of Set 6 | mitu
# Processing Record 21 of Set 6 | vilyuchinsk
# Processing Record 22 of Set 6 | harda khas
# Processing Record 23 of Set 6 | sesimbra
# Processing Record 24 of Set 6 | changling
# Processing Record 25 of Set 6 | klyuchi
# Processing Record 26 of Set 6 | magong
# Processing Record 27 of Set 6 | sidmouth
# Processing Record 28 of Set 6 | kittila
# Processing Record 29 of Set 6 | la passe
# Processing Record 30 of Set 6 | tamanrasset
# Processing Record 31 of Set 6 | pisco
# Processing Record 32 of Set 6 | nar'yan-mar
# Processing Record 33 of Set 6 | jucurutu
# Processing Record 34 of Set 6 | st. john's
# Processing Record 35 of Set 6 | puerto cabezas
# Processing Record 36 of Set 6 | kuala terengganu
# Processing Record 37 of Set 6 | flin flon
# Processing Record 38 of Set 6 | myrina
# Processing Record 39 of Set 6 | margaret river
# Processing Record 40 of Set 6 | ciudad pemex
# Processing Record 41 of Set 6 | lospalos
# Processing Record 42 of Set 6 | saint-francois
# Processing Record 43 of Set 6 | vorgashor
# Processing Record 44 of Set 6 | ust'-ilimsk
# Processing Record 45 of Set 6 | sept-iles
# Processing Record 46 of Set 6 | sinabang
# Processing Record 47 of Set 6 | tolanaro
# Processing Record 48 of Set 6 | high river
# Processing Record 49 of Set 6 | san andres
# Processing Record 0 of Set 7 | mossendjo
# Processing Record 1 of Set 7 | new norfolk
# Processing Record 2 of Set 7 | novoishimskiy
# Processing Record 3 of Set 7 | ingeniero guillermo n. juarez
# Processing Record 4 of Set 7 | el matama
# Processing Record 5 of Set 7 | celestun
# Processing Record 6 of Set 7 | bocas del toro
# Processing Record 7 of Set 7 | urucara
# Processing Record 8 of Set 7 | neiafu
# Processing Record 9 of Set 7 | hilo
# Processing Record 10 of Set 7 | fort mcmurray
# Processing Record 11 of Set 7 | mazatlan
# Processing Record 12 of Set 7 | sidney
# Processing Record 13 of Set 7 | praia da vitoria
# Processing Record 14 of Set 7 | dedham
# Processing Record 15 of Set 7 | lambarene
# Processing Record 16 of Set 7 | verkh-tula
# Processing Record 17 of Set 7 | daru
# Processing Record 18 of Set 7 | dilling
# Processing Record 19 of Set 7 | lensk
# Processing Record 20 of Set 7 | fannuj
# City fannuj not found. Skipping/...
# Processing Record 21 of Set 7 | isiolo
# Processing Record 22 of Set 7 | khandyga
# Processing Record 23 of Set 7 | badnawar
# Processing Record 24 of Set 7 | port macquarie
# Processing Record 25 of Set 7 | new castle
# Processing Record 26 of Set 7 | east london
# Processing Record 27 of Set 7 | luderitz
# Processing Record 28 of Set 7 | lautoka
# Processing Record 29 of Set 7 | constantia
# Processing Record 30 of Set 7 | kodiak
# Processing Record 31 of Set 7 | rundu
# Processing Record 32 of Set 7 | castillos
# Processing Record 33 of Set 7 | ust-nera
# Processing Record 34 of Set 7 | hirara
# Processing Record 35 of Set 7 | chandler
# Processing Record 36 of Set 7 | marsh harbour
# Processing Record 37 of Set 7 | saipan
# Processing Record 38 of Set 7 | segezha
# Processing Record 39 of Set 7 | masterton
# Processing Record 40 of Set 7 | pervomayskoye
# Processing Record 41 of Set 7 | kayangel
# Processing Record 42 of Set 7 | necochea
# Processing Record 43 of Set 7 | la ronge
# Processing Record 44 of Set 7 | broome
# Processing Record 45 of Set 7 | constitucion
# Processing Record 46 of Set 7 | villa huidobro
# Processing Record 47 of Set 7 | angol
# Processing Record 48 of Set 7 | george town
# Processing Record 49 of Set 7 | san martin hidalgo
# Processing Record 0 of Set 8 | lere
# Processing Record 1 of Set 8 | khanty-mansiysk
# Processing Record 2 of Set 8 | hobyo
# Processing Record 3 of Set 8 | namtsy
# Processing Record 4 of Set 8 | capao bonito
# Processing Record 5 of Set 8 | mana
# Processing Record 6 of Set 8 | kourou
# Processing Record 7 of Set 8 | sainte-marie
# Processing Record 8 of Set 8 | sao joao batista
# Processing Record 9 of Set 8 | ghat
# Processing Record 10 of Set 8 | roccella ionica
# Processing Record 11 of Set 8 | toga village
# City toga village not found. Skipping/...
# Processing Record 12 of Set 8 | bathsheba
# Processing Record 13 of Set 8 | timbuktu
# Processing Record 14 of Set 8 | priob'ye
# Processing Record 15 of Set 8 | 'izbat al burj
# City 'izbat al burj not found. Skipping/...
# Processing Record 16 of Set 8 | san luis
# Processing Record 17 of Set 8 | mayen abun
# City mayen abun not found. Skipping/...
# Processing Record 18 of Set 8 | lillestrom
# Processing Record 19 of Set 8 | faya-largeau
# Processing Record 20 of Set 8 | birjand
# Processing Record 21 of Set 8 | east wenatchee bench
# Processing Record 22 of Set 8 | le port
# Processing Record 23 of Set 8 | mata-utu
# Processing Record 24 of Set 8 | shalkar
# Processing Record 25 of Set 8 | al qutayfah
# Processing Record 26 of Set 8 | padang mat sirat
# City padang mat sirat not found. Skipping/...
# Processing Record 27 of Set 8 | urengoy
# Processing Record 28 of Set 8 | roosevelt
# Processing Record 29 of Set 8 | meadow lake
# Processing Record 30 of Set 8 | enewetak
# Processing Record 31 of Set 8 | urangan
# Processing Record 32 of Set 8 | suntar
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | wyszkow
# Processing Record 35 of Set 8 | dwarka
# Processing Record 36 of Set 8 | matthew town
# Processing Record 37 of Set 8 | walvis bay
# Processing Record 38 of Set 8 | malakanagiri
# Processing Record 39 of Set 8 | moyale
# Processing Record 40 of Set 8 | quincy
# Processing Record 41 of Set 8 | labytnangi
# Processing Record 42 of Set 8 | 'ain deheb
# Processing Record 43 of Set 8 | khovd
# Processing Record 44 of Set 8 | maunabo
# Processing Record 45 of Set 8 | itoman
# Processing Record 46 of Set 8 | washington
# Processing Record 47 of Set 8 | santana
# Processing Record 48 of Set 8 | gadzhiyevo
# Processing Record 49 of Set 8 | mutsu
# Processing Record 0 of Set 9 | mount pleasant
# Processing Record 1 of Set 9 | thames
# Processing Record 2 of Set 9 | cat ba
# City cat ba not found. Skipping/...
# Processing Record 3 of Set 9 | margate
# Processing Record 4 of Set 9 | grand falls-windsor
# Processing Record 5 of Set 9 | naliya
# Processing Record 6 of Set 9 | bubaque
# Processing Record 7 of Set 9 | mumford
# Processing Record 8 of Set 9 | hasaki
# Processing Record 9 of Set 9 | fale old settlement
# Processing Record 10 of Set 9 | igoumenitsa
# Processing Record 11 of Set 9 | sonsorol village
# City sonsorol village not found. Skipping/...
# Processing Record 12 of Set 9 | boyolangu
# Processing Record 13 of Set 9 | al bawiti
# Processing Record 14 of Set 9 | puerto quijarro
# Processing Record 15 of Set 9 | crane
# Processing Record 16 of Set 9 | lata
# Processing Record 17 of Set 9 | mikhaylovka
# Processing Record 18 of Set 9 | weno
# Processing Record 19 of Set 9 | basotu
# Processing Record 20 of Set 9 | anshun
# Processing Record 21 of Set 9 | saldanha
# Processing Record 22 of Set 9 | kilindoni
# Processing Record 23 of Set 9 | solwezi
# Processing Record 24 of Set 9 | kaluga
# Processing Record 25 of Set 9 | panjab
# Processing Record 26 of Set 9 | nadi
# Processing Record 27 of Set 9 | pokaran
# Processing Record 28 of Set 9 | al-`ula
# City al-`ula not found. Skipping/...
# Processing Record 29 of Set 9 | rongelap
# Processing Record 30 of Set 9 | zarichne
# Processing Record 31 of Set 9 | chonchi
# Processing Record 32 of Set 9 | berber
# Processing Record 33 of Set 9 | robertsport
# Processing Record 34 of Set 9 | yanykurgan
# Processing Record 35 of Set 9 | imbituba
# Processing Record 36 of Set 9 | gueckedou
# Processing Record 37 of Set 9 | sarangani
# Processing Record 38 of Set 9 | diamond springs
# Processing Record 39 of Set 9 | anqing
# Processing Record 40 of Set 9 | lamia
# Processing Record 41 of Set 9 | newman
# Processing Record 42 of Set 9 | new river
# Processing Record 43 of Set 9 | ciudad lazaro cardenas
# Processing Record 44 of Set 9 | ritchie
# Processing Record 45 of Set 9 | potosi
# Processing Record 46 of Set 9 | shimoda
# Processing Record 47 of Set 9 | kampene
# Processing Record 48 of Set 9 | divnogorsk
# Processing Record 49 of Set 9 | krasnovishersk
# Processing Record 0 of Set 10 | laguna
# Processing Record 1 of Set 10 | utete
# Processing Record 2 of Set 10 | namibe
# Processing Record 3 of Set 10 | lubumbashi
# Processing Record 4 of Set 10 | puerto baquerizo moreno
# Processing Record 5 of Set 10 | atar
# Processing Record 6 of Set 10 | zeya
# Processing Record 7 of Set 10 | ijuw
# City ijuw not found. Skipping/...
# Processing Record 8 of Set 10 | tandalti
# Processing Record 9 of Set 10 | loango
# Processing Record 10 of Set 10 | solnechnyy
# Processing Record 11 of Set 10 | vernon
# Processing Record 12 of Set 10 | el abiodh sidi cheikh
# Processing Record 13 of Set 10 | verkhniy mamon
# Processing Record 14 of Set 10 | cruzeiro do sul
# Processing Record 15 of Set 10 | douglas
# Processing Record 16 of Set 10 | quatre cocos
# Processing Record 17 of Set 10 | el porvenir
# Processing Record 18 of Set 10 | ust'-barguzin
# Processing Record 19 of Set 10 | summerside
# Processing Record 20 of Set 10 | hjorring
# Processing Record 21 of Set 10 | albertina
# Processing Record 22 of Set 10 | shingu
# Processing Record 23 of Set 10 | cidade velha
# Processing Record 24 of Set 10 | middlebury (village)
# Processing Record 25 of Set 10 | bermejillo
# Processing Record 26 of Set 10 | chinde
# Processing Record 27 of Set 10 | tudela de duero
# Processing Record 28 of Set 10 | mount isa
# Processing Record 29 of Set 10 | poronaysk
# Processing Record 30 of Set 10 | bushland beach
# City bushland beach not found. Skipping/...
# Processing Record 31 of Set 10 | farafangana
# Processing Record 32 of Set 10 | manta
# Processing Record 33 of Set 10 | byron bay
# Processing Record 34 of Set 10 | castelli
# Processing Record 35 of Set 10 | santa cruz de la sierra
# Processing Record 36 of Set 10 | ha tinh
# Processing Record 37 of Set 10 | kolwezi
# Processing Record 38 of Set 10 | beitbridge
# Processing Record 39 of Set 10 | saynshand
# Processing Record 40 of Set 10 | tema
# Processing Record 41 of Set 10 | privolzhskiy
# Processing Record 42 of Set 10 | kulia village
# City kulia village not found. Skipping/...
# Processing Record 43 of Set 10 | tobelo
# Processing Record 44 of Set 10 | virginia
# Processing Record 45 of Set 10 | alice springs
# Processing Record 46 of Set 10 | bogorodsk
# Processing Record 47 of Set 10 | brokopondo
# Processing Record 48 of Set 10 | karratha
# Processing Record 49 of Set 10 | rikaze
# Processing Record 0 of Set 11 | ketchikan
# Processing Record 1 of Set 11 | heroica matamoros
# Processing Record 2 of Set 11 | olavarria
# Processing Record 3 of Set 11 | tranovaho
# City tranovaho not found. Skipping/...
# Processing Record 4 of Set 11 | temiskaming shores
# Processing Record 5 of Set 11 | fortuna
# Processing Record 6 of Set 11 | tayu
# Processing Record 7 of Set 11 | bor
# Processing Record 8 of Set 11 | savanna-la-mar
# Processing Record 9 of Set 11 | black point
# Processing Record 10 of Set 11 | bengkulu
# Processing Record 11 of Set 11 | sinop
# Processing Record 12 of Set 11 | oppdal
# Processing Record 13 of Set 11 | turinskaya sloboda
# Processing Record 14 of Set 11 | sechura
# Processing Record 15 of Set 11 | warmbad
# Processing Record 16 of Set 11 | gillette
# Processing Record 17 of Set 11 | taltal
# Processing Record 18 of Set 11 | hammerfest
# Processing Record 19 of Set 11 | san patricio
# Processing Record 20 of Set 11 | uturoa
# Processing Record 21 of Set 11 | rouissat
# Processing Record 22 of Set 11 | nejo
# Processing Record 23 of Set 11 | tyukalinsk
# Processing Record 24 of Set 11 | tual
# Processing Record 25 of Set 11 | pandan
# Processing Record 26 of Set 11 | happy valley-goose bay
# Processing Record 27 of Set 11 | riedenburg
# Processing Record 28 of Set 11 | alo
# Processing Record 29 of Set 11 | kelaat mgouna
# City kelaat mgouna not found. Skipping/...
# Processing Record 30 of Set 11 | along
# Processing Record 31 of Set 11 | arkadak
# Processing Record 32 of Set 11 | minas de marcona
# Processing Record 33 of Set 11 | kanniyakumari
# Processing Record 34 of Set 11 | mulayjah
# Processing Record 35 of Set 11 | kas
# Processing Record 36 of Set 11 | naantali
# Processing Record 37 of Set 11 | embi
# Processing Record 38 of Set 11 | gizo
# Processing Record 39 of Set 11 | santo antonio do ica
# Processing Record 40 of Set 11 | weining
# Processing Record 41 of Set 11 | soledad de doblado
# Processing Record 42 of Set 11 | turbat
# Processing Record 43 of Set 11 | newnham
# Processing Record 44 of Set 11 | villa gesell
# Processing Record 45 of Set 11 | kota bharu
# Processing Record 46 of Set 11 | mariehamn
# Processing Record 47 of Set 11 | nahiyat ash shinafiyah
# Processing Record 48 of Set 11 | nouadhibou
# Processing Record 49 of Set 11 | nemuro
# Processing Record 0 of Set 12 | jiutai
# Processing Record 1 of Set 12 | teluk nibung
# Processing Record 2 of Set 12 | namdrik
# Processing Record 3 of Set 12 | aranyaprathet
# Processing Record 4 of Set 12 | bayan nur
# City bayan nur not found. Skipping/...
# Processing Record 5 of Set 12 | east end
# Processing Record 6 of Set 12 | tangalle
# Processing Record 7 of Set 12 | alotau
# City alotau not found. Skipping/...
# Processing Record 8 of Set 12 | yreka
# Processing Record 9 of Set 12 | cuito
# Processing Record 10 of Set 12 | bestobe
# Processing Record 11 of Set 12 | peterhead
# Processing Record 12 of Set 12 | mejit
# Processing Record 13 of Set 12 | palangkaraya
# Processing Record 14 of Set 12 | hakui
# Processing Record 15 of Set 12 | sao jose da coroa grande
# Processing Record 16 of Set 12 | zharkent
# Processing Record 17 of Set 12 | arteche
# Processing Record 18 of Set 12 | altus
# Processing Record 19 of Set 12 | aktau
# Processing Record 20 of Set 12 | heinola
# Processing Record 21 of Set 12 | sao vicente
# Processing Record 22 of Set 12 | camana
# Processing Record 23 of Set 12 | pruzhany
# Processing Record 24 of Set 12 | winejok
# City winejok not found. Skipping/...
# Processing Record 25 of Set 12 | mao
# Processing Record 26 of Set 12 | picui
# Processing Record 27 of Set 12 | gonabad
# Processing Record 28 of Set 12 | hutchinson
# Processing Record 29 of Set 12 | rawlins
# Processing Record 30 of Set 12 | sungai raya
# Processing Record 31 of Set 12 | lhokseumawe
# Processing Record 32 of Set 12 | egilsstadir
# Processing Record 33 of Set 12 | tindouf
# Processing Record 34 of Set 12 | inirida
# Processing Record 35 of Set 12 | yeniseysk
# Processing Record 36 of Set 12 | tehuitzingo
# Processing Record 37 of Set 12 | mossel bay
# Processing Record 38 of Set 12 | n'dalatando
# Processing Record 39 of Set 12 | camarinas
# Processing Record 40 of Set 12 | axim
# Processing Record 41 of Set 12 | aliabad
# Processing Record 42 of Set 12 | mae tha
# Processing Record 43 of Set 12 | silver springs
# Processing Record 44 of Set 12 | kolondieba
# Processing Record 45 of Set 12 | zuni pueblo
# Processing Record 46 of Set 12 | marat
# Processing Record 47 of Set 12 | acarau
# Processing Record 48 of Set 12 | banyo
# Processing Record 49 of Set 12 | sulak
# Processing Record 0 of Set 13 | sorong
# Processing Record 1 of Set 13 | pokhara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       longyearbyen  78.2186   15.6401     -4.09        68          40
# 1            tir pul  34.5943   61.2690      8.14        44          90
# 2     puerto natales -51.7236  -72.4875     13.25        44          40
# 3  port-aux-francais -49.3500   70.2167      5.02        83         100
# 4      mount gambier -37.8333  140.7667      9.08        85         100
#
#    Wind Speed Country        Date
# 0        8.75      SJ  1701888056
# 1        0.96      AF  1701888279
# 2        9.26      CL  1701888063
# 3        9.02      TF  1701888054
# 4        1.48      AU  1701887936

# %%
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %% [markdown]
# ### Import csv

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             longyearbyen  78.2186   15.6401     -4.09        68          40
# 1                  tir pul  34.5943   61.2690      8.14        44          90
# 2           puerto natales -51.7236  -72.4875     13.25        44          40
# 3        port-aux-francais -49.3500   70.2167      5.02        83         100
# 4            mount gambier -37.8333  140.7667      9.08        85         100
#
#          Wind Speed Country        Date
# City_ID
# 0              8.75      SJ  1701888056
# 1              0.96      AF  1701888279
# 2              9.26      CL  1701888063
# 3              9.02      TF  1701888054
# 4              1.48      AU  1701887936

# %% [markdown]
# ### Create the Scatter Plots
#
# #### Latitude Vs. Temperature

# %%
city_data_df.plot(x = 'Lat', y = 'Max Temp', kind = 'scatter', edgecolors = 'black', s = 30)
plt.title('Latitude vs. Max Temp')
plt.xlabel('Latitude')
plt.grid()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
city_data_df.plot(x = 'Lat', y = 'Humidity', kind = 'scatter', edgecolors = 'black', s = 30)
plt.title('Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.grid()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
city_data_df.plot(x = 'Lat', y = 'Cloudiness', kind = 'scatter', edgecolors = 'black', s = 30)
plt.title('Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.grid()

# %%
city_data_df.plot(x = 'Lat', y = 'Wind Speed', kind = 'scatter', edgecolors = 'black', s = 30)
plt.title('Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.grid()

# %% [markdown]
# ---
#
# ## Compute Linear Regression for Each Relationship

# %%
def plot_lin_regress(x_val, y_val):
    slope, y_int, _, __, ___ = linregress(x_val, y_val)
    fit = slope * x_val + y_int

    plt.scatter(x_val, y_val, label = 'data', edgecolors = 'black', s = 30)
    plt.plot(x_val, fit, color = 'white', label = 'fit', 
             path_effects=[pe.withStroke(linewidth=4, foreground="black")],
             ms = 100)
    plt.legend(loc = 'best')
    return slope, y_int

# %%
north_lat = city_data_df.loc[city_data_df['Lat'] >= 0]
south_lat = city_data_df.loc[city_data_df['Lat'] <= 0]
x_val_north = north_lat['Lat']
x_val_south = south_lat['Lat']

y_val_temp_north = north_lat['Max Temp']

slope, y_int = plot_lin_regress(x_val_north, y_val_temp_north)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Temperature correlation in the Northern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (10, -20),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()

# %%
y_val_temp_south = south_lat['Max Temp']

slope, y_int = plot_lin_regress(x_val_south, y_val_temp_south)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Temperature correlation in the Southern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (-20, 5),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
y_val_humidity_north = north_lat['Humidity']

slope, y_int = plot_lin_regress(x_val_north, y_val_humidity_north)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity correlation in the northern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (50, 30),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()

# %%
y_val_humidity_south = south_lat['Humidity']

slope, y_int = plot_lin_regress(x_val_south, y_val_humidity_south)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity correlation in the Southern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (-50, 30),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
y_val_cloudiness_north = north_lat['Cloudiness']

slope, y_int = plot_lin_regress(x_val_north, y_val_cloudiness_north)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness correlation in the northern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (51, 30),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()

# %%
y_val_cloudiness_south = south_lat['Cloudiness']

slope, y_int = plot_lin_regress(x_val_south, y_val_cloudiness_south)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness correlation in the southern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (-55, 20),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
y_val_ws_north = north_lat['Wind Speed']

slope, y_int = plot_lin_regress(x_val_north, y_val_ws_north)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Wind Speed correlation in the northern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (50, 12),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()

# %%
y_val_ws_south = south_lat['Wind Speed']

slope, y_int = plot_lin_regress(x_val_south, y_val_ws_south)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Wind Speed correlation in the southern Hemisphere')

str_eq = f'{slope:.2f}x + {y_int:.2f}'
plt.annotate(str_eq, (-52, 9),fontsize=15,
             color='white',
              path_effects=[pe.withStroke(linewidth=2, foreground="black")])
plt.show()
