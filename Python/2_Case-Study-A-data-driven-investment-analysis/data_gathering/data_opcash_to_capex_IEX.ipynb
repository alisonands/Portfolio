# %%
import requests
import pandas as pd
from api_keys import IEX_api

# %%
data = pd.read_csv('../data/tech.csv').dropna(how = 'any', axis = 0)
data = data.sort_values(by='Market Cap', ascending=False).reset_index()
symbols = data['Symbol']

# %%
# ticker = 'AAPL'
period = 'annual'
last = '30'

# %% [raw]
# # gathering symbols
# url = f'https://api.iex.cloud/v1/data/core/REF_DATA?token={IEX_api}'
# ref_data = requests.get(url).json()
# symbols = []
# for i in range(len(ref_data)):
#     if ref_data[i]['region'] == 'US':
#         symbols.append(ref_data[i]['symbol'])

# %% [raw]
# #balance sheet
# strategy = 'balance_sheet'
#
# # url = f'https://api.iex.cloud/v1/data/core/{strategy}/{ticker}/?token={IEX_api}'
# url = f'https://api.iex.cloud/v1/data/core/{strategy}/{ticker}/{period}?last={last}&token={IEX_api}'
# response = requests.get(url)
# balance_sheet = response.json()
# response

# %% [raw]
# #cash_flow
# strategy = 'cash_flow'
# url = f'https://api.iex.cloud/v1/data/core/{strategy}/{ticker}/{period}?last={last}&token={IEX_api}'
# response = requests.get(url)
# cash_flow = response.json()
# response

# %% [raw]
# #income statement
# strategy = 'income'
# url = f'https://api.iex.cloud/v1/data/core/{strategy}/{ticker}/{period}?last={last}&token={IEX_api}'
# response = requests.get(url)
# income_statement = response.json()
# response

# %% [raw]
# fundamentals[0].keys()
# opcash_to_capex = pd.DataFrame({
#     'date':'',
#     'Operating cash flow': '',
#     'ticker': 'AAPL',
#     'capex': ''
# }, index = range(0))
# temp = {'date': fundamentals[0]['date'],
#         'Operating cash flow': fundamentals[0]['cashFlowOperating'],
#         'ticker': 'AAPL',
#         'capex': fundamentals[0]['capex']}
# temp = pd.DataFrame(temp, index=[0])
# opcash_to_capex = pd.concat([opcash_to_capex, temp], ignore_index=True)
# opcash_to_capex

# %%
#fundamentals
strategy = 'fundamentals'
stocks_not_found = []
opcash_to_capex = pd.DataFrame({
    'date':'',
    'Operating cash flow': '',
    'ticker': '',
    'capex': ''
}, index = range(0))
for j in range(len(symbols)):
    try:
        print(f'gathering data stock {j} of {len(symbols)}...')
        url = f'https://api.iex.cloud/v1/data/core/{strategy}/{symbols[j]}/{period}?last={last}&token={IEX_api}'
        response = requests.get(url)
        fundamentals = response.json()
        for i in range(len(fundamentals)):
            row = {'date': fundamentals[i]['date'],
                'Operating cash flow': fundamentals[i]['cashFlowOperating'],
                'ticker': symbols[j],
                'capex': fundamentals[i]['capex']}
            row = pd.DataFrame(row, index = [0])
            opcash_to_capex = pd.concat([opcash_to_capex, row], ignore_index=True)
    except:
        stocks_not_found.append(symbols[j])
        print(f'stock {symbols[j]} not found. moving on...')

opcash_to_capex['date'] = pd.to_datetime(opcash_to_capex['date'], unit = 'ms').dt.year
opcash_to_capex['Operating cash flow to capex'] =abs(opcash_to_capex['capex']/opcash_to_capex['Operating cash flow'] * 100)
opcash_to_capex.set_index('date')
# Out:
# gathering data stock 0 of 519...
# gathering data stock 1 of 519...
# gathering data stock 2 of 519...
# gathering data stock 3 of 519...
# gathering data stock 4 of 519...
# gathering data stock 5 of 519...
# gathering data stock 6 of 519...
# gathering data stock 7 of 519...
# gathering data stock 8 of 519...
# gathering data stock 9 of 519...
# gathering data stock 10 of 519...
# gathering data stock 11 of 519...
# gathering data stock 12 of 519...
# gathering data stock 13 of 519...
# gathering data stock 14 of 519...
# gathering data stock 15 of 519...
# gathering data stock 16 of 519...
# gathering data stock 17 of 519...
# gathering data stock 18 of 519...
# gathering data stock 19 of 519...
# gathering data stock 20 of 519...
# gathering data stock 21 of 519...
# gathering data stock 22 of 519...
# gathering data stock 23 of 519...
# gathering data stock 24 of 519...
# gathering data stock 25 of 519...
# gathering data stock 26 of 519...
# gathering data stock 27 of 519...
# gathering data stock 28 of 519...
# gathering data stock 29 of 519...
# gathering data stock 30 of 519...
# gathering data stock 31 of 519...
# gathering data stock 32 of 519...
# gathering data stock 33 of 519...
# gathering data stock 34 of 519...
# gathering data stock 35 of 519...
# gathering data stock 36 of 519...
# gathering data stock 37 of 519...
# gathering data stock 38 of 519...
# gathering data stock 39 of 519...
# gathering data stock 40 of 519...
# gathering data stock 41 of 519...
# gathering data stock 42 of 519...
# gathering data stock 43 of 519...
# gathering data stock 44 of 519...
# gathering data stock 45 of 519...
# gathering data stock 46 of 519...
# gathering data stock 47 of 519...
# gathering data stock 48 of 519...
# gathering data stock 49 of 519...
# gathering data stock 50 of 519...
# gathering data stock 51 of 519...
# gathering data stock 52 of 519...
# gathering data stock 53 of 519...
# gathering data stock 54 of 519...
# gathering data stock 55 of 519...
# gathering data stock 56 of 519...
# gathering data stock 57 of 519...
# gathering data stock 58 of 519...
# gathering data stock 59 of 519...
# gathering data stock 60 of 519...
# gathering data stock 61 of 519...
# gathering data stock 62 of 519...
# gathering data stock 63 of 519...
# gathering data stock 64 of 519...
# gathering data stock 65 of 519...
# gathering data stock 66 of 519...
# gathering data stock 67 of 519...
# gathering data stock 68 of 519...
# gathering data stock 69 of 519...
# gathering data stock 70 of 519...
# gathering data stock 71 of 519...
# gathering data stock 72 of 519...
# gathering data stock 73 of 519...
# gathering data stock 74 of 519...
# gathering data stock 75 of 519...
# gathering data stock 76 of 519...
# gathering data stock 77 of 519...
# gathering data stock 78 of 519...
# gathering data stock 79 of 519...
# gathering data stock 80 of 519...
# gathering data stock 81 of 519...
# gathering data stock 82 of 519...
# gathering data stock 83 of 519...
# gathering data stock 84 of 519...
# gathering data stock 85 of 519...
# gathering data stock 86 of 519...
# gathering data stock 87 of 519...
# gathering data stock 88 of 519...
# gathering data stock 89 of 519...
# gathering data stock 90 of 519...
# gathering data stock 91 of 519...
# gathering data stock 92 of 519...
# gathering data stock 93 of 519...
# gathering data stock 94 of 519...
# gathering data stock 95 of 519...
# gathering data stock 96 of 519...
# gathering data stock 97 of 519...
# gathering data stock 98 of 519...
# gathering data stock 99 of 519...
# gathering data stock 100 of 519...
# gathering data stock 101 of 519...
# gathering data stock 102 of 519...
# gathering data stock 103 of 519...
# gathering data stock 104 of 519...
# gathering data stock 105 of 519...
# gathering data stock 106 of 519...
# gathering data stock 107 of 519...
# gathering data stock 108 of 519...
# gathering data stock 109 of 519...
# gathering data stock 110 of 519...
# gathering data stock 111 of 519...
# gathering data stock 112 of 519...
# gathering data stock 113 of 519...
# gathering data stock 114 of 519...
# gathering data stock 115 of 519...
# gathering data stock 116 of 519...
# gathering data stock 117 of 519...
# gathering data stock 118 of 519...
# gathering data stock 119 of 519...
# gathering data stock 120 of 519...
# gathering data stock 121 of 519...
# gathering data stock 122 of 519...
# gathering data stock 123 of 519...
# gathering data stock 124 of 519...
# gathering data stock 125 of 519...
# gathering data stock 126 of 519...
# gathering data stock 127 of 519...
# gathering data stock 128 of 519...
# gathering data stock 129 of 519...
# gathering data stock 130 of 519...
# gathering data stock 131 of 519...
# gathering data stock 132 of 519...
# gathering data stock 133 of 519...
# gathering data stock 134 of 519...
# gathering data stock 135 of 519...
# gathering data stock 136 of 519...
# gathering data stock 137 of 519...
# gathering data stock 138 of 519...
# gathering data stock 139 of 519...
# gathering data stock 140 of 519...
# gathering data stock 141 of 519...
# gathering data stock 142 of 519...
# gathering data stock 143 of 519...
# gathering data stock 144 of 519...
# gathering data stock 145 of 519...
# gathering data stock 146 of 519...
# gathering data stock 147 of 519...
# gathering data stock 148 of 519...
# gathering data stock 149 of 519...
# gathering data stock 150 of 519...
# gathering data stock 151 of 519...
# gathering data stock 152 of 519...
# gathering data stock 153 of 519...
# gathering data stock 154 of 519...
# gathering data stock 155 of 519...
# gathering data stock 156 of 519...
# gathering data stock 157 of 519...
# gathering data stock 158 of 519...
# gathering data stock 159 of 519...
# gathering data stock 160 of 519...
# gathering data stock 161 of 519...
# gathering data stock 162 of 519...
# gathering data stock 163 of 519...
# gathering data stock 164 of 519...
# gathering data stock 165 of 519...
# gathering data stock 166 of 519...
# gathering data stock 167 of 519...
# gathering data stock 168 of 519...
# gathering data stock 169 of 519...
# gathering data stock 170 of 519...
# gathering data stock 171 of 519...
# gathering data stock 172 of 519...
# gathering data stock 173 of 519...
# gathering data stock 174 of 519...
# gathering data stock 175 of 519...
# gathering data stock 176 of 519...
# gathering data stock 177 of 519...
# gathering data stock 178 of 519...
# gathering data stock 179 of 519...
# gathering data stock 180 of 519...
# gathering data stock 181 of 519...
# gathering data stock 182 of 519...
# gathering data stock 183 of 519...
# gathering data stock 184 of 519...
# gathering data stock 185 of 519...
# gathering data stock 186 of 519...
# gathering data stock 187 of 519...
# gathering data stock 188 of 519...
# gathering data stock 189 of 519...
# gathering data stock 190 of 519...
# gathering data stock 191 of 519...
# gathering data stock 192 of 519...
# gathering data stock 193 of 519...
# gathering data stock 194 of 519...
# gathering data stock 195 of 519...
# gathering data stock 196 of 519...
# gathering data stock 197 of 519...
# gathering data stock 198 of 519...
# gathering data stock 199 of 519...
# gathering data stock 200 of 519...
# gathering data stock 201 of 519...
# gathering data stock 202 of 519...
# gathering data stock 203 of 519...
# gathering data stock 204 of 519...
# gathering data stock 205 of 519...
# gathering data stock 206 of 519...
# gathering data stock 207 of 519...
# gathering data stock 208 of 519...
# gathering data stock 209 of 519...
# gathering data stock 210 of 519...
# gathering data stock 211 of 519...
# gathering data stock 212 of 519...
# gathering data stock 213 of 519...
# gathering data stock 214 of 519...
# gathering data stock 215 of 519...
# gathering data stock 216 of 519...
# gathering data stock 217 of 519...
# gathering data stock 218 of 519...
# gathering data stock 219 of 519...
# gathering data stock 220 of 519...
# gathering data stock 221 of 519...
# gathering data stock 222 of 519...
# gathering data stock 223 of 519...
# gathering data stock 224 of 519...
# gathering data stock 225 of 519...
# gathering data stock 226 of 519...
# gathering data stock 227 of 519...
# gathering data stock 228 of 519...
# gathering data stock 229 of 519...
# gathering data stock 230 of 519...
# gathering data stock 231 of 519...
# gathering data stock 232 of 519...
# gathering data stock 233 of 519...
# gathering data stock 234 of 519...
# gathering data stock 235 of 519...
# gathering data stock 236 of 519...
# gathering data stock 237 of 519...
# gathering data stock 238 of 519...
# gathering data stock 239 of 519...
# gathering data stock 240 of 519...
# gathering data stock 241 of 519...
# gathering data stock 242 of 519...
# gathering data stock 243 of 519...
# gathering data stock 244 of 519...
# gathering data stock 245 of 519...
# gathering data stock 246 of 519...
# gathering data stock 247 of 519...
# gathering data stock 248 of 519...
# gathering data stock 249 of 519...
# gathering data stock 250 of 519...
# gathering data stock 251 of 519...
# gathering data stock 252 of 519...
# gathering data stock 253 of 519...
# gathering data stock 254 of 519...
# gathering data stock 255 of 519...
# gathering data stock 256 of 519...
# gathering data stock 257 of 519...
# gathering data stock 258 of 519...
# gathering data stock 259 of 519...
# gathering data stock 260 of 519...
# gathering data stock 261 of 519...
# gathering data stock 262 of 519...
# gathering data stock 263 of 519...
# gathering data stock 264 of 519...
# gathering data stock 265 of 519...
# gathering data stock 266 of 519...
# gathering data stock 267 of 519...
# gathering data stock 268 of 519...
# gathering data stock 269 of 519...
# gathering data stock 270 of 519...
# gathering data stock 271 of 519...
# gathering data stock 272 of 519...
# gathering data stock 273 of 519...
# gathering data stock 274 of 519...
# gathering data stock 275 of 519...
# gathering data stock 276 of 519...
# gathering data stock 277 of 519...
# gathering data stock 278 of 519...
# gathering data stock 279 of 519...
# gathering data stock 280 of 519...
# gathering data stock 281 of 519...
# gathering data stock 282 of 519...
# gathering data stock 283 of 519...
# gathering data stock 284 of 519...
# gathering data stock 285 of 519...
# gathering data stock 286 of 519...
# gathering data stock 287 of 519...
# gathering data stock 288 of 519...
# gathering data stock 289 of 519...
# gathering data stock 290 of 519...
# gathering data stock 291 of 519...
# gathering data stock 292 of 519...
# gathering data stock 293 of 519...
# gathering data stock 294 of 519...
# gathering data stock 295 of 519...
# gathering data stock 296 of 519...
# gathering data stock 297 of 519...
# gathering data stock 298 of 519...
# gathering data stock 299 of 519...
# gathering data stock 300 of 519...
# gathering data stock 301 of 519...
# gathering data stock 302 of 519...
# gathering data stock 303 of 519...
# gathering data stock 304 of 519...
# gathering data stock 305 of 519...
# gathering data stock 306 of 519...
# gathering data stock 307 of 519...
# gathering data stock 308 of 519...
# gathering data stock 309 of 519...
# gathering data stock 310 of 519...
# gathering data stock 311 of 519...
# gathering data stock 312 of 519...
# gathering data stock 313 of 519...
# gathering data stock 314 of 519...
# gathering data stock 315 of 519...
# gathering data stock 316 of 519...
# gathering data stock 317 of 519...
# gathering data stock 318 of 519...
# gathering data stock 319 of 519...
# gathering data stock 320 of 519...
# gathering data stock 321 of 519...
# gathering data stock 322 of 519...
# gathering data stock 323 of 519...
# gathering data stock 324 of 519...
# gathering data stock 325 of 519...
# gathering data stock 326 of 519...
# gathering data stock 327 of 519...
# gathering data stock 328 of 519...
# gathering data stock 329 of 519...
# gathering data stock 330 of 519...
# gathering data stock 331 of 519...
# gathering data stock 332 of 519...
# gathering data stock 333 of 519...
# gathering data stock 334 of 519...
# gathering data stock 335 of 519...
# gathering data stock 336 of 519...
# gathering data stock 337 of 519...
# gathering data stock 338 of 519...
# gathering data stock 339 of 519...
# gathering data stock 340 of 519...
# gathering data stock 341 of 519...
# gathering data stock 342 of 519...
# gathering data stock 343 of 519...
# gathering data stock 344 of 519...
# gathering data stock 345 of 519...
# gathering data stock 346 of 519...
# gathering data stock 347 of 519...
# gathering data stock 348 of 519...
# gathering data stock 349 of 519...
# gathering data stock 350 of 519...
# gathering data stock 351 of 519...
# gathering data stock 352 of 519...
# gathering data stock 353 of 519...
# gathering data stock 354 of 519...
# gathering data stock 355 of 519...
# gathering data stock 356 of 519...
# gathering data stock 357 of 519...
# gathering data stock 358 of 519...
# gathering data stock 359 of 519...
# gathering data stock 360 of 519...
# gathering data stock 361 of 519...
# gathering data stock 362 of 519...
# gathering data stock 363 of 519...
# gathering data stock 364 of 519...
# gathering data stock 365 of 519...
# gathering data stock 366 of 519...
# gathering data stock 367 of 519...
# gathering data stock 368 of 519...
# gathering data stock 369 of 519...
# gathering data stock 370 of 519...
# gathering data stock 371 of 519...
# gathering data stock 372 of 519...
# gathering data stock 373 of 519...
# gathering data stock 374 of 519...
# gathering data stock 375 of 519...
# gathering data stock 376 of 519...
# gathering data stock 377 of 519...
# gathering data stock 378 of 519...
# gathering data stock 379 of 519...
# gathering data stock 380 of 519...
# gathering data stock 381 of 519...
# gathering data stock 382 of 519...
# gathering data stock 383 of 519...
# gathering data stock 384 of 519...
# gathering data stock 385 of 519...
# gathering data stock 386 of 519...
# gathering data stock 387 of 519...
# gathering data stock 388 of 519...
# gathering data stock 389 of 519...
# gathering data stock 390 of 519...
# gathering data stock 391 of 519...
# gathering data stock 392 of 519...
# gathering data stock 393 of 519...
# gathering data stock 394 of 519...
# gathering data stock 395 of 519...
# gathering data stock 396 of 519...
# gathering data stock 397 of 519...
# gathering data stock 398 of 519...
# gathering data stock 399 of 519...
# gathering data stock 400 of 519...
# gathering data stock 401 of 519...
# gathering data stock 402 of 519...
# gathering data stock 403 of 519...
# gathering data stock 404 of 519...
# gathering data stock 405 of 519...
# gathering data stock 406 of 519...
# gathering data stock 407 of 519...
# gathering data stock 408 of 519...
# gathering data stock 409 of 519...
# gathering data stock 410 of 519...
# gathering data stock 411 of 519...
# gathering data stock 412 of 519...
# gathering data stock 413 of 519...
# gathering data stock 414 of 519...
# gathering data stock 415 of 519...
# gathering data stock 416 of 519...
# gathering data stock 417 of 519...
# gathering data stock 418 of 519...
# gathering data stock 419 of 519...
# gathering data stock 420 of 519...
# gathering data stock 421 of 519...
# gathering data stock 422 of 519...
# gathering data stock 423 of 519...
# gathering data stock 424 of 519...
# gathering data stock 425 of 519...
# gathering data stock 426 of 519...
# gathering data stock 427 of 519...
# gathering data stock 428 of 519...
# gathering data stock 429 of 519...
# gathering data stock 430 of 519...
# gathering data stock 431 of 519...
# gathering data stock 432 of 519...
# gathering data stock 433 of 519...
# gathering data stock 434 of 519...
# gathering data stock 435 of 519...
# gathering data stock 436 of 519...
# gathering data stock 437 of 519...
# gathering data stock 438 of 519...
# gathering data stock 439 of 519...
# gathering data stock 440 of 519...
# gathering data stock 441 of 519...
# gathering data stock 442 of 519...
# gathering data stock 443 of 519...
# gathering data stock 444 of 519...
# gathering data stock 445 of 519...
# gathering data stock 446 of 519...
# gathering data stock 447 of 519...
# gathering data stock 448 of 519...
# gathering data stock 449 of 519...
# gathering data stock 450 of 519...
# gathering data stock 451 of 519...
# gathering data stock 452 of 519...
# gathering data stock 453 of 519...
# gathering data stock 454 of 519...
# gathering data stock 455 of 519...
# gathering data stock 456 of 519...
# gathering data stock 457 of 519...
# gathering data stock 458 of 519...
# gathering data stock 459 of 519...
# gathering data stock 460 of 519...
# gathering data stock 461 of 519...
# gathering data stock 462 of 519...
# gathering data stock 463 of 519...
# gathering data stock 464 of 519...
# gathering data stock 465 of 519...
# gathering data stock 466 of 519...
# gathering data stock 467 of 519...
# gathering data stock 468 of 519...
# gathering data stock 469 of 519...
# gathering data stock 470 of 519...
# gathering data stock 471 of 519...
# gathering data stock 472 of 519...
# gathering data stock 473 of 519...
# gathering data stock 474 of 519...
# gathering data stock 475 of 519...
# gathering data stock 476 of 519...
# gathering data stock 477 of 519...
# gathering data stock 478 of 519...
# gathering data stock 479 of 519...
# gathering data stock 480 of 519...
# gathering data stock 481 of 519...
# gathering data stock 482 of 519...
# gathering data stock 483 of 519...
# gathering data stock 484 of 519...
# gathering data stock 485 of 519...
# gathering data stock 486 of 519...
# gathering data stock 487 of 519...
# gathering data stock 488 of 519...
# gathering data stock 489 of 519...
# gathering data stock 490 of 519...
# gathering data stock 491 of 519...
# gathering data stock 492 of 519...
# gathering data stock 493 of 519...
# gathering data stock 494 of 519...
# gathering data stock 495 of 519...
# gathering data stock 496 of 519...
# gathering data stock 497 of 519...
# gathering data stock 498 of 519...
# gathering data stock 499 of 519...
# gathering data stock 500 of 519...
# gathering data stock 501 of 519...
# gathering data stock 502 of 519...
# gathering data stock 503 of 519...
# gathering data stock 504 of 519...
# gathering data stock 505 of 519...
# gathering data stock 506 of 519...
# gathering data stock 507 of 519...
# gathering data stock 508 of 519...
# gathering data stock 509 of 519...
# gathering data stock 510 of 519...
# gathering data stock 511 of 519...
# gathering data stock 512 of 519...
# gathering data stock 513 of 519...
# gathering data stock 514 of 519...
# gathering data stock 515 of 519...
# gathering data stock 516 of 519...
# gathering data stock 517 of 519...
# gathering data stock 518 of 519...
#      Operating cash flow ticker         capex Operating cash flow to capex
# date
# 2023        110543000000   AAPL  -10959000000                     9.913789
# 2022        122151000000   AAPL  -10708000000                     8.766199
# 2021        104038000000   AAPL  -11085000000                    10.654761
# 2020         80674000000   AAPL   -7309000000                      9.05992
# 2019         69391000000   AAPL  -10495000000                     15.12444
# ...                  ...    ...           ...                          ...
# 2022           -17514000   WISA        -43000                     0.245518
# 2021           -11508000   WISA        -99000                     0.860271
# 2020            -9859000   WISA        -52000                     0.527437
# 2019           -11032000   WISA        -35000                     0.317259
# 2018            -9952150   WISA        -86793                     0.872103
#
# [3903 rows x 4 columns]

# %%
opcash_to_capex = opcash_to_capex[~(opcash_to_capex['capex'] == 0)]
# opcash_to_capex['capex'] = opcash_to_capex['capex'] * -1
opcash_to_capex.to_csv('opcash_to_capex_tech.csv')
