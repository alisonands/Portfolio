# %%
import pandas as pd
from api_keys import AV_api
import requests

# %%
url = 'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

data.keys()
# Out:
# {'fiscalDateEnding': '2023-09-30',
#  'reportedCurrency': 'USD',
#  'grossProfit': '8023000000',
#  'totalRevenue': '14752000000',
#  'costOfRevenue': '6729000000',
#  'costofGoodsAndServicesSold': '42000000',
#  'operatingIncome': '1994000000',
#  'sellingGeneralAndAdministrative': '4458000000',
#  'researchAndDevelopment': '1685000000',
#  'operatingExpenses': '6029000000',
#  'investmentIncomeNet': 'None',
#  'netInterestIncome': '-412000000',
#  'interestIncome': '156000000',
#  'interestExpense': '412000000',
#  'nonInterestIncome': '265000000',
#  'otherNonOperatingIncome': '97000000',
#  'depreciation': '521000000',
#  'depreciationAndAmortization': '572000000',
#  'incomeBeforeTax': '1863000000',
#  'incomeTaxExpense': '159000000',
#  'interestAndDebtExpense': '412000000',
#  'netIncomeFromContinuingOperations': '1714000000',
#  'comprehensiveIncomeNetOfTax': '2105000000',
#  'ebit': '2275000000',
#  'ebitda': '2847000000',
#  'netIncome': '1704000000'}

# %%
pd.DataFrame(data['quarterlyReports']).columns
# Out:
# Index(['fiscalDateEnding', 'reportedCurrency', 'grossProfit', 'totalRevenue',
#        'costOfRevenue', 'costofGoodsAndServicesSold', 'operatingIncome',
#        'sellingGeneralAndAdministrative', 'researchAndDevelopment',
#        'operatingExpenses', 'investmentIncomeNet', 'netInterestIncome',
#        'interestIncome', 'interestExpense', 'nonInterestIncome',
#        'otherNonOperatingIncome', 'depreciation',
#        'depreciationAndAmortization', 'incomeBeforeTax', 'incomeTaxExpense',
#        'interestAndDebtExpense', 'netIncomeFromContinuingOperations',
#        'comprehensiveIncomeNetOfTax', 'ebit', 'ebitda', 'netIncome'],
#       dtype='object')

# %%
url = 'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

pd.DataFrame(data['quarterlyReports']).columns
# Out:
# Index(['fiscalDateEnding', 'reportedCurrency', 'totalAssets',
#        'totalCurrentAssets', 'cashAndCashEquivalentsAtCarryingValue',
#        'cashAndShortTermInvestments', 'inventory', 'currentNetReceivables',
#        'totalNonCurrentAssets', 'propertyPlantEquipment',
#        'accumulatedDepreciationAmortizationPPE', 'intangibleAssets',
#        'intangibleAssetsExcludingGoodwill', 'goodwill', 'investments',
#        'longTermInvestments', 'shortTermInvestments', 'otherCurrentAssets',
#        'otherNonCurrentAssets', 'totalLiabilities', 'totalCurrentLiabilities',
#        'currentAccountsPayable', 'deferredRevenue', 'currentDebt',
#        'shortTermDebt', 'totalNonCurrentLiabilities',
#        'capitalLeaseObligations', 'longTermDebt', 'currentLongTermDebt',
#        'longTermDebtNoncurrent', 'shortLongTermDebtTotal',
#        'otherCurrentLiabilities', 'otherNonCurrentLiabilities',
#        'totalShareholderEquity', 'treasuryStock', 'retainedEarnings',
# ...

# %%
url = 'https://www.alphavantage.co/query?function=CASH_FLOW&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

pd.DataFrame(data['annualReports'])
# Out:
#   fiscalDateEnding reportedCurrency operatingCashflow  \
# 0       2022-12-31              USD       10435000000
# 1       2021-12-31              USD       12796000000
# 2       2020-12-31              USD       18197000000
# 3       2019-12-31              USD       14770000000
# 4       2018-12-31              USD       15247000000
#
#   paymentsForOperatingActivities proceedsFromOperatingActivities  \
# 0                     2430000000                            None
# 1                     2655000000                            None
# 2                     3406000000                            None
# 3                     3234000000                            None
# 4                     1423000000                            None
#
#   changeInOperatingLiabilities changeInOperatingAssets  \
# 0                    213000000               468000000
# 1                     85000000             -1510000000
# 2                    138000000             -5088000000
# ...

# %%
import csv

CSV_URL = 'https://www.alphavantage.co/query?function=EARNINGS_CALENDAR&horizon=3month&apikey=demo'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
    for row in my_list:
        print(row)
# Out:
# ['symbol', 'name', 'reportDate', 'fiscalDateEnding', 'estimate', 'currency']
# ['A', 'Agilent Technologies Inc', '2024-02-26', '2024-01-31', '1.22', 'USD']
# ['AA', 'Alcoa Corp', '2024-01-16', '2023-12-31', '-0.77', 'USD']
# ['AACAY', 'AACAY', '2024-03-21', '2023-12-31', '0.0373', 'CNY']
# ['AACG', 'ATA Creativity Global', '2024-03-28', '2023-12-31', '', 'CNY']
# ['AACTF', 'AACTF', '2024-02-28', '2023-12-31', '', 'USD']
# ['AADI', 'Aadi Bioscience Inc', '2024-03-26', '2023-12-31', '-0.65', 'USD']
# ['AAGIY', 'AAGIY', '2024-03-08', '2023-12-31', '1.18', 'USD']
# ['AAGRY', 'AAGRY', '2024-02-21', '2023-12-31', '0', 'IDR']
# ['AAIC', 'Arlington Asset Investment Corp - Class A', '2024-03-29', '2023-12-31', '0.05', 'USD']
# ['AAIGF', 'AAIGF', '2024-03-08', '2023-12-31', '0.2952', 'USD']
# ['AAIRD', 'AAIRD', '2024-04-03', '2024-03-31', '', 'CAD']
# ['AAIRF', 'AAIRF', '2024-04-03', '2024-03-31', '', 'CAD']
# ['AAL', 'American Airlines Group Inc', '2024-01-24', '2023-12-31', '0.06', 'USD']
# ...

# %%
symbol = 'AAPL'
function = 'CASH_FLOW'
url = f'https://www.alphavantage.co/query?function={function}&symbol={symbol}&apikey={AV_api}'
